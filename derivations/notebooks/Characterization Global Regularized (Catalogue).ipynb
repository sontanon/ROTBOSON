# %%
from pylab import *
from scipy.stats import linregress as linregress
import os

# %%
dirnames = [x[0] for x in os.walk("../Catalogue2/")][:]

# %%
dirnames

# %%
l = np.zeros(len(dirnames), dtype=int)
N = np.zeros(len(dirnames), dtype=int)
w = np.zeros(len(dirnames))
dr = np.zeros(len(dirnames))
M_Komar1 = np.zeros(len(dirnames))
M_Komar2 = np.zeros(len(dirnames))
J_Komar1 = np.zeros(len(dirnames))
J_Komar2 = np.zeros(len(dirnames))
phi_max = np.zeros(len(dirnames))
rr_max = np.zeros(len(dirnames))
min_alpha = np.zeros(len(dirnames))
min_beta = np.zeros(len(dirnames))
max_metric = np.zeros(len(dirnames))
max_a_metric = np.zeros(len(dirnames))
max_psi = np.zeros(len(dirnames))
min_lambda = np.zeros(len(dirnames))
r99 = np.zeros(len(dirnames))
ergoregion = np.zeros(len(dirnames), dtype=int)

# %%
ghost = 2

# %%
for i in range(len(dirnames)):
    # Get dirname.
    dirname = dirnames[i]
    
    # Get parameters.
    l[i], dr[i], N[i] = int(dirnames[i][4]), float64(dirnames[i][23:34]), int(dirnames[i][-4:])
    #print("Processing file l = %d, w = %1.5E, dr = %1.5E, N =%04d" % (l[i], w[i], dr[i], N[i]))

    # Axis.
    r_l = np.linspace(dr[i] * (0.5 - ghost), dr[i] * (N[i] + ghost - 0.5), N[i] + 2 * ghost)
    
    # Sanity checks.
    #if not(os.path.isfile(dirname + "/M_Komar1.asc")):
    #    print("Warning M_Komar1.asc does not exist in %d, %s!" % (i, dirname))
    #    continue
    #elif not(os.path.isfile(dirname + "/M_Komar2.asc")):
    #    print("Warning M_Komar2.asc does not exist in %d, %s!" % (i, dirname))
    #    continue
    #elif not(os.path.isfile(dirname + "/J_Komar1.asc")):
    #    print("Warning J_Komar2.asc does not exist in %d, %s!" % (i, dirname))
    #    continue
    #elif not(os.path.isfile(dirname + "/J_Komar2.asc")):
    #    print("Warning J_Komar2.asc does not exist in %d, %s!" % (i, dirname))
    #    continue
    #elif not(os.path.isfile(dirname + "/psi_f.asc")):
    #    print("Warning psi_f.asc does not exist in %d, %s!" % (i, dirname))
    #    continue

    # Get frequency, masses, and angular momenta.
    w[i] = np.genfromtxt(dirname + "/w_f.asc").item()
    M_Komar1[i] = np.genfromtxt(dirname + "/M_Komar1.asc", skip_header = N[i]).item()
    M_Komar2[i] = np.genfromtxt(dirname + "/M_Komar2.asc", skip_header = N[i]).item()
    J_Komar1[i] = np.genfromtxt(dirname + "/J_Komar1.asc", skip_header = N[i]).item()
    J_Komar2[i] = np.genfromtxt(dirname + "/J_Komar2.asc", skip_header = N[i]).item()

    # Import psi to get phi's maximum value and coordinate.
    min_alpha[i] = np.min(np.exp(np.genfromtxt(dirname + "/log_alpha_f.asc", usecols = ghost)))
    min_beta[i]  = np.min(np.genfromtxt(dirname + "/beta_f.asc", usecols = ghost))
    max_metric[i]   = np.max(np.exp(2.0 * np.genfromtxt(dirname + "/log_a_f.asc", usecols = ghost)))
    max_a_metric[i] = np.max(np.exp(2.0 * np.genfromtxt(dirname + "/log_h_f.asc", usecols = ghost)))
    max_psi[i] = np.genfromtxt(dirname + "/sph_psi_f.asc", usecols = 0, max_rows = 1)
    min_lambda[i] = np.min(np.genfromtxt(dirname + "/lambda_f.asc", usecols = ghost))
    
    phi_max[i] = np.genfromtxt(dirname + "/phi_max.asc", usecols = 0, max_rows = 1)
    rr_max[i] = np.genfromtxt(dirname + "/rr_phi_max.asc", usecols = 0, max_rows = 1)
    r99[i] = np.genfromtxt(dirname + "/r99.asc", usecols = 0, max_rows = 1)
    ergoregion[i] = np.genfromtxt(dirname + "/ergoregion_flag.asc", usecols = 0, max_rows = 1)

# %%
l = l[max_psi.argsort()]
N = N[max_psi.argsort()]
w = w[max_psi.argsort()]
dr = dr[max_psi.argsort()]
M_Komar1 = M_Komar1[max_psi.argsort()]
M_Komar2 = M_Komar2[max_psi.argsort()]
J_Komar1 = J_Komar1[max_psi.argsort()]
J_Komar2 = J_Komar2[max_psi.argsort()]
phi_max = phi_max[max_psi.argsort()]
rr_max = rr_max[max_psi.argsort()]
r99 = r99[max_psi.argsort()]
ergoregion = ergoregion[max_psi.argsort()]
min_alpha = min_alpha[max_psi.argsort()]
min_beta = min_beta[max_psi.argsort()]
max_metric = max_metric[max_psi.argsort()]
max_a_metric = max_a_metric[max_psi.argsort()]
min_lambda = min_lambda[max_psi.argsort()]

# %%
k_max = rr_max / dr

# %%
array_dirnames = np.array(dirnames)
array_dirnames = array_dirnames[max_psi.argsort()]

# %%
pwd()

# %%
from shutil import move

# %%
for dirname in aaray_dirnames:
    move(dirname, "../Catalogue2/" + dirname[2:])

# %%
max_psi = max_psi[max_psi.argsort()]

# %%
fig, ax = plt.subplots(figsize = (16, 12), nrows=2, ncols=2)

plt.suptitle(r"Characterization for RBS $l \in [1,\,6]$")

ax[0][0].set_title("Mass")
#ax[0][0].plot(w[l == 1][dr[l == 1] == 0.08], -2.25 + 2.0 * r99[l == 1][dr[l == 1] == 0.08] / (M_Komar1[l == 1][dr[l == 1] == 0.08] + M_Komar2[l == 1][dr[l == 1] == 0.08]), ".-", label = r"$l = 1$")
ax[0][0].plot(w[l == 1][dr[l == 1] == 0.08], 0.5 * (M_Komar1[l == 1][dr[l == 1] == 0.08] + M_Komar2[l == 1][dr[l == 1] == 0.08]), ".-", label = r"$l = 1$")
ax[0][0].plot(w[l == 2][dr[l == 2] == 0.08], 0.5 * (M_Komar1[l == 2][dr[l == 2] == 0.08] + M_Komar2[l == 2][dr[l == 2] == 0.08]), ".-", label = r"$l = 2$")
ax[0][0].plot(w[l == 3][dr[l == 3] == 0.08], 0.5 * (M_Komar1[l == 3][dr[l == 3] == 0.08] + M_Komar2[l == 3][dr[l == 3] == 0.08]), ".-", label = r"$l = 3$")
ax[0][0].plot(w[l == 4][dr[l == 4] == 0.08], 0.5 * (M_Komar1[l == 4][dr[l == 4] == 0.08] + M_Komar2[l == 4][dr[l == 4] == 0.08]), ".-", label = r"$l = 4$")
ax[0][0].plot(w[l == 5][dr[l == 5] == 0.08], 0.5 * (M_Komar1[l == 5][dr[l == 5] == 0.08] + M_Komar2[l == 5][dr[l == 5] == 0.08]), ".-", label = r"$l = 5$")
ax[0][0].plot(w[l == 6][dr[l == 6] == 0.08], 0.5 * (M_Komar1[l == 6][dr[l == 6] == 0.08] + M_Komar2[l == 6][dr[l == 6] == 0.08]), ".-", label = r"$l = 6$")

ax[0][0].plot(w[l == 1][dr[l == 1] == 0.04], 0.5 * (M_Komar1[l == 1][dr[l == 1] == 0.04] + M_Komar2[l == 1][dr[l == 1] == 0.04]), ".-")
ax[0][0].plot(w[l == 2][dr[l == 2] == 0.04], 0.5 * (M_Komar1[l == 2][dr[l == 2] == 0.04] + M_Komar2[l == 2][dr[l == 2] == 0.04]), ".-")
ax[0][0].plot(w[l == 3][dr[l == 3] == 0.04], 0.5 * (M_Komar1[l == 3][dr[l == 3] == 0.04] + M_Komar2[l == 3][dr[l == 3] == 0.04]), ".-")
ax[0][0].plot(w[l == 4][dr[l == 4] == 0.04], 0.5 * (M_Komar1[l == 4][dr[l == 4] == 0.04] + M_Komar2[l == 4][dr[l == 4] == 0.04]), ".-")
ax[0][0].plot(w[l == 5][dr[l == 5] == 0.04], 0.5 * (M_Komar1[l == 5][dr[l == 5] == 0.04] + M_Komar2[l == 5][dr[l == 5] == 0.04]), ".-")
ax[0][0].plot(w[l == 6][dr[l == 6] == 0.04], 0.5 * (M_Komar1[l == 6][dr[l == 6] == 0.04] + M_Komar2[l == 6][dr[l == 6] == 0.04]), ".-")

ax[0][0].plot(w[l == 1][dr[l == 1] == 0.02], 0.5 * (M_Komar1[l == 1][dr[l == 1] == 0.02] + M_Komar2[l == 1][dr[l == 1] == 0.02]), ".-")
ax[0][0].plot(w[l == 2][dr[l == 2] == 0.02], 0.5 * (M_Komar1[l == 2][dr[l == 2] == 0.02] + M_Komar2[l == 2][dr[l == 2] == 0.02]), ".-")
ax[0][0].plot(w[l == 3][dr[l == 3] == 0.02], 0.5 * (M_Komar1[l == 3][dr[l == 3] == 0.02] + M_Komar2[l == 3][dr[l == 3] == 0.02]), ".-")
ax[0][0].plot(w[l == 4][dr[l == 4] == 0.02], 0.5 * (M_Komar1[l == 4][dr[l == 4] == 0.02] + M_Komar2[l == 4][dr[l == 4] == 0.02]), ".-")
ax[0][0].plot(w[l == 5][dr[l == 5] == 0.02], 0.5 * (M_Komar1[l == 5][dr[l == 5] == 0.02] + M_Komar2[l == 5][dr[l == 5] == 0.02]), ".-")
ax[0][0].plot(w[l == 6][dr[l == 6] == 0.02], 0.5 * (M_Komar1[l == 6][dr[l == 6] == 0.02] + M_Komar2[l == 6][dr[l == 6] == 0.02]), ".-")
ax[0][0].legend()
ax[0][0].set_xlabel(r"$\omega\;[m/\hbar]$")
ax[0][0].set_ylabel(r"$M\;[m^2_P/m]$")
#ax[0][0].set_ylim(0, 8)
#ax[0][0].set_xlim(0.3, 1.0)

ax[0][1].set_title("Angular Momentum")
ax[0][1].plot(w[l == 1][dr[l == 1] == 0.08], 0.5 * (J_Komar1[l == 1][dr[l == 1] == 0.08] + J_Komar2[l == 1][dr[l == 1] == 0.08]), ".-", label = r"$l = 1$")
ax[0][1].plot(w[l == 2][dr[l == 2] == 0.08], 0.5 * (J_Komar1[l == 2][dr[l == 2] == 0.08] + J_Komar2[l == 2][dr[l == 2] == 0.08]), ".-", label = r"$l = 2$")
ax[0][1].plot(w[l == 3][dr[l == 3] == 0.08], 0.5 * (J_Komar1[l == 3][dr[l == 3] == 0.08] + J_Komar2[l == 3][dr[l == 3] == 0.08]), ".-", label = r"$l = 3$")
ax[0][1].plot(w[l == 4][dr[l == 4] == 0.08], 0.5 * (J_Komar1[l == 4][dr[l == 4] == 0.08] + J_Komar2[l == 4][dr[l == 4] == 0.08]), ".-", label = r"$l = 4$")
ax[0][1].plot(w[l == 5][dr[l == 5] == 0.08], 0.5 * (J_Komar1[l == 5][dr[l == 5] == 0.08] + J_Komar2[l == 5][dr[l == 5] == 0.08]), ".-", label = r"$l = 5$")
ax[0][1].plot(w[l == 6][dr[l == 6] == 0.08], 0.5 * (J_Komar1[l == 6][dr[l == 6] == 0.08] + J_Komar2[l == 6][dr[l == 6] == 0.08]), ".-", label = r"$l = 6$")

ax[0][1].plot(w[l == 1][dr[l == 1] == 0.04], 0.5 * (J_Komar1[l == 1][dr[l == 1] == 0.04] + J_Komar2[l == 1][dr[l == 1] == 0.04]), ".-")
ax[0][1].plot(w[l == 2][dr[l == 2] == 0.04], 0.5 * (J_Komar1[l == 2][dr[l == 2] == 0.04] + J_Komar2[l == 2][dr[l == 2] == 0.04]), ".-")
ax[0][1].plot(w[l == 3][dr[l == 3] == 0.04], 0.5 * (J_Komar1[l == 3][dr[l == 3] == 0.04] + J_Komar2[l == 3][dr[l == 3] == 0.04]), ".-")
ax[0][1].plot(w[l == 4][dr[l == 4] == 0.04], 0.5 * (J_Komar1[l == 4][dr[l == 4] == 0.04] + J_Komar2[l == 4][dr[l == 4] == 0.04]), ".-")
ax[0][1].plot(w[l == 5][dr[l == 5] == 0.04], 0.5 * (J_Komar1[l == 5][dr[l == 5] == 0.04] + J_Komar2[l == 5][dr[l == 5] == 0.04]), ".-")
ax[0][1].plot(w[l == 6][dr[l == 6] == 0.04], 0.5 * (J_Komar1[l == 6][dr[l == 6] == 0.04] + J_Komar2[l == 6][dr[l == 6] == 0.04]), ".-")

ax[0][1].plot(w[l == 1][dr[l == 1] == 0.02], 0.5 * (J_Komar1[l == 1][dr[l == 1] == 0.02] + J_Komar2[l == 1][dr[l == 1] == 0.02]), ".-")
ax[0][1].plot(w[l == 2][dr[l == 2] == 0.02], 0.5 * (J_Komar1[l == 2][dr[l == 2] == 0.02] + J_Komar2[l == 2][dr[l == 2] == 0.02]), ".-")
ax[0][1].plot(w[l == 3][dr[l == 3] == 0.02], 0.5 * (J_Komar1[l == 3][dr[l == 3] == 0.02] + J_Komar2[l == 3][dr[l == 3] == 0.02]), ".-")
ax[0][1].plot(w[l == 4][dr[l == 4] == 0.02], 0.5 * (J_Komar1[l == 4][dr[l == 4] == 0.02] + J_Komar2[l == 4][dr[l == 4] == 0.02]), ".-")
ax[0][1].plot(w[l == 5][dr[l == 5] == 0.02], 0.5 * (J_Komar1[l == 5][dr[l == 5] == 0.02] + J_Komar2[l == 5][dr[l == 5] == 0.02]), ".-")
ax[0][1].plot(w[l == 6][dr[l == 6] == 0.02], 0.5 * (J_Komar1[l == 6][dr[l == 6] == 0.02] + J_Komar2[l == 6][dr[l == 6] == 0.02]), ".-")
ax[0][1].legend()
ax[0][1].set_xlabel(r"$\omega\;[m/\hbar]$")
ax[0][1].set_ylabel(r"$J\;[(m^2_P/m)^2]$")
#ax[0][1].set_ylim(0, 60)
#ax[0][1].set_xlim(0.3, 1.0)

ax[1][0].set_title("Scalar Field Maximum")
ax[1][0].plot(phi_max[l == 1][dr[l == 1] == 0.08], w[l == 1][dr[l == 1] == 0.08], ".-", label = r"$l = 1$")
ax[1][0].plot(phi_max[l == 2][dr[l == 2] == 0.08], w[l == 2][dr[l == 2] == 0.08], ".-", label = r"$l = 2$")
ax[1][0].plot(phi_max[l == 3][dr[l == 3] == 0.08], w[l == 3][dr[l == 3] == 0.08], ".-", label = r"$l = 3$")
ax[1][0].plot(phi_max[l == 4][dr[l == 4] == 0.08], w[l == 4][dr[l == 4] == 0.08], ".-", label = r"$l = 4$")
ax[1][0].plot(phi_max[l == 5][dr[l == 5] == 0.08], w[l == 5][dr[l == 5] == 0.08], ".-", label = r"$l = 5$")
ax[1][0].plot(phi_max[l == 6][dr[l == 6] == 0.08], w[l == 6][dr[l == 6] == 0.08], ".-", label = r"$l = 6$")

ax[1][0].plot(phi_max[l == 1][dr[l == 1] == 0.04], w[l == 1][dr[l == 1] == 0.04], ".-")
ax[1][0].plot(phi_max[l == 2][dr[l == 2] == 0.04], w[l == 2][dr[l == 2] == 0.04], ".-")
ax[1][0].plot(phi_max[l == 3][dr[l == 3] == 0.04], w[l == 3][dr[l == 3] == 0.04], ".-")
ax[1][0].plot(phi_max[l == 4][dr[l == 4] == 0.04], w[l == 4][dr[l == 4] == 0.04], ".-")
ax[1][0].plot(phi_max[l == 5][dr[l == 5] == 0.04], w[l == 5][dr[l == 5] == 0.04], ".-")
ax[1][0].plot(phi_max[l == 6][dr[l == 6] == 0.04], w[l == 6][dr[l == 6] == 0.04], ".-")

ax[1][0].plot(phi_max[l == 1][dr[l == 1] == 0.02], w[l == 1][dr[l == 1] == 0.02], ".-")
ax[1][0].plot(phi_max[l == 2][dr[l == 2] == 0.02], w[l == 2][dr[l == 2] == 0.02], ".-")
ax[1][0].plot(phi_max[l == 3][dr[l == 3] == 0.02], w[l == 3][dr[l == 3] == 0.02], ".-")
ax[1][0].plot(phi_max[l == 4][dr[l == 4] == 0.02], w[l == 4][dr[l == 4] == 0.02], ".-")
ax[1][0].plot(phi_max[l == 5][dr[l == 5] == 0.02], w[l == 5][dr[l == 5] == 0.02], ".-")
ax[1][0].plot(phi_max[l == 6][dr[l == 6] == 0.02], w[l == 6][dr[l == 6] == 0.02], ".-")
ax[1][0].legend()
ax[1][0].set_xlabel(r"$\max(\phi)$")
ax[1][0].set_ylabel(r"$\omega\;[m/\hbar]$")
#ax[1][0].set_ylim(0.3, 1.0)
#ax[1][0].set_xlim(0, 0.15)

ax[1][1].set_title("Scalar Field Maximum Radial Coordinate")
ax[1][1].plot(rr_max[l == 1][dr[l == 1] == 0.08], 0.5 * (M_Komar1[l == 1][dr[l == 1] == 0.08] + M_Komar2[l == 1][dr[l == 1] == 0.08]), ".-", label = r"$l = 1$")
ax[1][1].plot(rr_max[l == 2][dr[l == 2] == 0.08], 0.5 * (M_Komar1[l == 2][dr[l == 2] == 0.08] + M_Komar2[l == 2][dr[l == 2] == 0.08]), ".-", label = r"$l = 2$")
ax[1][1].plot(rr_max[l == 3][dr[l == 3] == 0.08], 0.5 * (M_Komar1[l == 3][dr[l == 3] == 0.08] + M_Komar2[l == 3][dr[l == 3] == 0.08]), ".-", label = r"$l = 3$")
ax[1][1].plot(rr_max[l == 4][dr[l == 4] == 0.08], 0.5 * (M_Komar1[l == 4][dr[l == 4] == 0.08] + M_Komar2[l == 4][dr[l == 4] == 0.08]), ".-", label = r"$l = 4$")
ax[1][1].plot(rr_max[l == 5][dr[l == 5] == 0.08], 0.5 * (M_Komar1[l == 5][dr[l == 5] == 0.08] + M_Komar2[l == 5][dr[l == 5] == 0.08]), ".-", label = r"$l = 5$")
ax[1][1].plot(rr_max[l == 6][dr[l == 6] == 0.08], 0.5 * (M_Komar1[l == 6][dr[l == 6] == 0.08] + M_Komar2[l == 6][dr[l == 6] == 0.08]), ".-", label = r"$l = 6$")

ax[1][1].plot(rr_max[l == 1][dr[l == 1] == 0.04], 0.5 * (M_Komar1[l == 1][dr[l == 1] == 0.04] + M_Komar2[l == 1][dr[l == 1] == 0.04]), ".-")
ax[1][1].plot(rr_max[l == 2][dr[l == 2] == 0.04], 0.5 * (M_Komar1[l == 2][dr[l == 2] == 0.04] + M_Komar2[l == 2][dr[l == 2] == 0.04]), ".-")
ax[1][1].plot(rr_max[l == 3][dr[l == 3] == 0.04], 0.5 * (M_Komar1[l == 3][dr[l == 3] == 0.04] + M_Komar2[l == 3][dr[l == 3] == 0.04]), ".-")
ax[1][1].plot(rr_max[l == 4][dr[l == 4] == 0.04], 0.5 * (M_Komar1[l == 4][dr[l == 4] == 0.04] + M_Komar2[l == 4][dr[l == 4] == 0.04]), ".-")
ax[1][1].plot(rr_max[l == 5][dr[l == 5] == 0.04], 0.5 * (M_Komar1[l == 5][dr[l == 5] == 0.04] + M_Komar2[l == 5][dr[l == 5] == 0.04]), ".-")
ax[1][1].plot(rr_max[l == 6][dr[l == 6] == 0.04], 0.5 * (M_Komar1[l == 6][dr[l == 6] == 0.04] + M_Komar2[l == 6][dr[l == 6] == 0.04]), ".-")

ax[1][1].plot(rr_max[l == 1][dr[l == 1] == 0.02], 0.5 * (M_Komar1[l == 1][dr[l == 1] == 0.02] + M_Komar2[l == 1][dr[l == 1] == 0.02]), ".-")
ax[1][1].plot(rr_max[l == 2][dr[l == 2] == 0.02], 0.5 * (M_Komar1[l == 2][dr[l == 2] == 0.02] + M_Komar2[l == 2][dr[l == 2] == 0.02]), ".-")
ax[1][1].plot(rr_max[l == 3][dr[l == 3] == 0.02], 0.5 * (M_Komar1[l == 3][dr[l == 3] == 0.02] + M_Komar2[l == 3][dr[l == 3] == 0.02]), ".-")
ax[1][1].plot(rr_max[l == 4][dr[l == 4] == 0.02], 0.5 * (M_Komar1[l == 4][dr[l == 4] == 0.02] + M_Komar2[l == 4][dr[l == 4] == 0.02]), ".-")
ax[1][1].plot(rr_max[l == 5][dr[l == 5] == 0.02], 0.5 * (M_Komar1[l == 5][dr[l == 5] == 0.02] + M_Komar2[l == 5][dr[l == 5] == 0.02]), ".-")
ax[1][1].plot(rr_max[l == 6][dr[l == 6] == 0.02], 0.5 * (M_Komar1[l == 6][dr[l == 6] == 0.02] + M_Komar2[l == 6][dr[l == 6] == 0.02]), ".-")
ax[1][1].legend()
ax[1][1].set_xlabel(r"$r-$coordinate of $\max(\phi)\;[\hbar/m]$")
ax[1][1].set_ylabel(r"$M\;[m^2_P/m]$")
#ax[1][1].set_ylim(0, 8)
#ax[1][1].set_xlim(0, 32)

plt.show()

# %%
fig, ax = plt.subplots(figsize = (16, 18), nrows=3, ncols=2)

plt.suptitle(r"Characterization for RBS $l = 1$")

ax[0][0].set_title(r"Lapse $\log\,\alpha$ Minimum Value")
ax[0][0].plot(max_psi[l == 1][dr[l == 1] == 8.0E-02], np.log(min_alpha[l == 1][dr[l == 1] == 8.0E-02]), ".-", label = r"$\Delta \rho = 8/100$")
ax[0][0].plot(max_psi[l == 1][dr[l == 1] == 4.0E-02], np.log(min_alpha[l == 1][dr[l == 1] == 4.0E-02]), ".-", label = r"$\Delta \rho = 4/100$")
ax[0][0].plot(max_psi[l == 1][dr[l == 1] == 2.0E-02], np.log(min_alpha[l == 1][dr[l == 1] == 2.0E-02]), ".-", label = r"$\Delta \rho = 2/100$")

ax[0][0].legend()
ax[0][0].set_xlabel(r"$\max(\psi)$")
ax[0][0].set_ylabel(r"$\min(\log\,\alpha)$")

ax[0][1].set_title(r"Shift $\beta$ Minimum Value")
ax[0][1].plot(max_psi[l == 1][dr[l == 1] == 8.0E-02], min_beta[l == 1][dr[l == 1] == 8.0E-02], ".-", label = r"$\Delta \rho = 8/100$")
ax[0][1].plot(max_psi[l == 1][dr[l == 1] == 4.0E-02], min_beta[l == 1][dr[l == 1] == 4.0E-02], ".-", label = r"$\Delta \rho = 4/100$")
ax[0][1].plot(max_psi[l == 1][dr[l == 1] == 2.0E-02], min_beta[l == 1][dr[l == 1] == 2.0E-02], ".-", label = r"$\Delta \rho = 2/100$")

ax[0][1].legend()
ax[0][1].set_xlabel(r"$\max(\psi)$")
ax[0][1].set_ylabel(r"$\min(\beta)$")

ax[1][0].set_title(r"Metric $\frac{1}{2}\,\log\,\gamma_{rr}$ Maximum Value")
ax[1][0].plot(max_psi[l == 1][dr[l == 1] == 8.0E-02], 0.5 * np.log(max_metric[l == 1][dr[l == 1] == 8.0E-02]), ".-", label = r"$\Delta \rho = 8/100$")
ax[1][0].plot(max_psi[l == 1][dr[l == 1] == 4.0E-02], 0.5 * np.log(max_metric[l == 1][dr[l == 1] == 4.0E-02]), ".-", label = r"$\Delta \rho = 4/100$")
ax[1][0].plot(max_psi[l == 1][dr[l == 1] == 2.0E-02], 0.5 * np.log(max_metric[l == 1][dr[l == 1] == 2.0E-02]), ".-", label = r"$\Delta \rho = 2/100$")

ax[1][0].legend()
ax[1][0].set_xlabel(r"$\max(\psi)$")
ax[1][0].set_ylabel(r"$\max(\log\,\gamma_{r r})$")

ax[1][1].set_title(r"Metric $\frac{1}{2}\,\log\,(\gamma_{\varphi \varphi} / \rho^2)$ Maximum Value")
ax[1][1].plot(max_psi[l == 1][dr[l == 1] == 8.0E-02], 0.5 * np.log(max_a_metric[l == 1][dr[l == 1] == 8.0E-02]), ".-", label = r"$\Delta \rho = 8/100$")
ax[1][1].plot(max_psi[l == 1][dr[l == 1] == 4.0E-02], 0.5 * np.log(max_a_metric[l == 1][dr[l == 1] == 4.0E-02]), ".-", label = r"$\Delta \rho = 4/100$")
ax[1][1].plot(max_psi[l == 1][dr[l == 1] == 2.0E-02], 0.5 * np.log(max_a_metric[l == 1][dr[l == 1] == 2.0E-02]), ".-", label = r"$\Delta \rho = 2/100$")

ax[1][1].legend()
ax[1][1].set_xlabel(r"$\max(\psi)$")
ax[1][1].set_ylabel(r"$\max(\log\,(\gamma_{\varphi \varphi}/\rho^2))$")

ax[2][0].set_title(r"Scalar Field Frequency $\omega$")
ax[2][0].plot(max_psi[l == 1][dr[l == 1] == 8.0E-02], w[l == 1][dr[l == 1] == 8.0E-02], ".-", label = r"$\omega = 8/100$")
ax[2][0].plot(max_psi[l == 1][dr[l == 1] == 4.0E-02], w[l == 1][dr[l == 1] == 4.0E-02], ".-", label = r"$\omega = 4/100$")
ax[2][0].plot(max_psi[l == 1][dr[l == 1] == 2.0E-02], w[l == 1][dr[l == 1] == 2.0E-02], ".-", label = r"$\omega = 2/100$")

ax[2][0].legend()
ax[2][0].set_xlabel(r"$\max(\psi)$")
ax[2][0].set_ylabel(r"$\omega$")

ax[2][1].set_title(r"Regularization Variable $\lambda$ Minimum Value")
ax[2][1].plot(max_psi[l == 1][dr[l == 1] == 8.0E-02], min_lambda[l == 1][dr[l == 1] == 8.0E-02], ".-", label = r"$\Delta \rho = 8/100$")
ax[2][1].plot(max_psi[l == 1][dr[l == 1] == 4.0E-02], min_lambda[l == 1][dr[l == 1] == 4.0E-02], ".-", label = r"$\Delta \rho = 4/100$")
ax[2][1].plot(max_psi[l == 1][dr[l == 1] == 2.0E-02], min_lambda[l == 1][dr[l == 1] == 2.0E-02], ".-", label = r"$\Delta \rho = 2/100$")

ax[2][1].legend()
ax[2][1].set_xlabel(r"$\max(\psi)$")
ax[2][1].set_ylabel(r"$\min(\lambda)$")

plt.show()

# %%
fig, ax = plt.subplots(figsize = (16, 18), nrows=3, ncols=2)

plt.suptitle(r"Characterization for RBS $l = 2$")

ax[0][0].set_title(r"Lapse $\log\,\alpha$ Minimum Value")
ax[0][0].plot(max_psi[l == 2][dr[l == 2] == 8.0E-02], np.log(min_alpha[l == 2][dr[l == 2] == 8.0E-02]), ".-", label = r"$\Delta \rho = 8/100$")
ax[0][0].plot(max_psi[l == 2][dr[l == 2] == 4.0E-02], np.log(min_alpha[l == 2][dr[l == 2] == 4.0E-02]), ".-", label = r"$\Delta \rho = 4/100$")
ax[0][0].plot(max_psi[l == 2][dr[l == 2] == 2.0E-02], np.log(min_alpha[l == 2][dr[l == 2] == 2.0E-02]), ".-", label = r"$\Delta \rho = 2/100$")

ax[0][0].legend()
ax[0][0].set_xlabel(r"$\max(\psi)$")
ax[0][0].set_ylabel(r"$\min(\log\,\alpha)$")

ax[0][1].set_title(r"Shift $\beta$ Minimum Value")
ax[0][1].plot(max_psi[l == 2][dr[l == 2] == 8.0E-02], min_beta[l == 2][dr[l == 2] == 8.0E-02], ".-", label = r"$\Delta \rho = 8/100$")
ax[0][1].plot(max_psi[l == 2][dr[l == 2] == 4.0E-02], min_beta[l == 2][dr[l == 2] == 4.0E-02], ".-", label = r"$\Delta \rho = 4/100$")
ax[0][1].plot(max_psi[l == 2][dr[l == 2] == 2.0E-02], min_beta[l == 2][dr[l == 2] == 2.0E-02], ".-", label = r"$\Delta \rho = 2/100$")

ax[0][1].legend()
ax[0][1].set_xlabel(r"$\max(\psi)$")
ax[0][1].set_ylabel(r"$\min(\beta)$")

ax[1][0].set_title(r"Metric $\frac{1}{2}\,\log\,\gamma_{rr}$ Maximum Value")
ax[1][0].plot(max_psi[l == 2][dr[l == 2] == 8.0E-02], 0.5 * np.log(max_metric[l == 2][dr[l == 2] == 8.0E-02]), ".-", label = r"$\Delta \rho = 8/100$")
ax[1][0].plot(max_psi[l == 2][dr[l == 2] == 4.0E-02], 0.5 * np.log(max_metric[l == 2][dr[l == 2] == 4.0E-02]), ".-", label = r"$\Delta \rho = 4/100$")
ax[1][0].plot(max_psi[l == 2][dr[l == 2] == 2.0E-02], 0.5 * np.log(max_metric[l == 2][dr[l == 2] == 2.0E-02]), ".-", label = r"$\Delta \rho = 2/100$")

ax[1][0].legend()
ax[1][0].set_xlabel(r"$\max(\psi)$")
ax[1][0].set_ylabel(r"$\max(\log\,\gamma_{r r})$")

ax[1][1].set_title(r"Metric $\frac{1}{2}\,\log\,(\gamma_{\varphi \varphi} / \rho^2)$ Maximum Value")
ax[1][1].plot(max_psi[l == 2][dr[l == 2] == 8.0E-02], 0.5 * np.log(max_a_metric[l == 2][dr[l == 2] == 8.0E-02]), ".-", label = r"$\Delta \rho = 8/100$")
ax[1][1].plot(max_psi[l == 2][dr[l == 2] == 4.0E-02], 0.5 * np.log(max_a_metric[l == 2][dr[l == 2] == 4.0E-02]), ".-", label = r"$\Delta \rho = 4/100$")
ax[1][1].plot(max_psi[l == 2][dr[l == 2] == 2.0E-02], 0.5 * np.log(max_a_metric[l == 2][dr[l == 2] == 2.0E-02]), ".-", label = r"$\Delta \rho = 2/100$")

ax[1][1].legend()
ax[1][1].set_xlabel(r"$\max(\psi)$")
ax[1][1].set_ylabel(r"$\max(\log\,(\gamma_{\varphi \varphi}/\rho^2))$")

ax[2][0].set_title(r"Scalar Field Frequency $\omega$")
ax[2][0].plot(max_psi[l == 2][dr[l == 2] == 8.0E-02], w[l == 2][dr[l == 2] == 8.0E-02], ".-", label = r"$\omega = 8/100$")
ax[2][0].plot(max_psi[l == 2][dr[l == 2] == 4.0E-02], w[l == 2][dr[l == 2] == 4.0E-02], ".-", label = r"$\omega = 4/100$")
ax[2][0].plot(max_psi[l == 2][dr[l == 2] == 2.0E-02], w[l == 2][dr[l == 2] == 2.0E-02], ".-", label = r"$\omega = 2/100$")

ax[2][0].legend()
ax[2][0].set_xlabel(r"$\max(\psi)$")
ax[2][0].set_ylabel(r"$\omega$")

ax[2][1].set_title(r"Regularization Variable $\lambda$ Minimum Value")
ax[2][1].plot(max_psi[l == 2][dr[l == 2] == 8.0E-02], min_lambda[l == 2][dr[l == 2] == 8.0E-02], ".-", label = r"$\Delta \rho = 8/100$")
ax[2][1].plot(max_psi[l == 2][dr[l == 2] == 4.0E-02], min_lambda[l == 2][dr[l == 2] == 4.0E-02], ".-", label = r"$\Delta \rho = 4/100$")
ax[2][1].plot(max_psi[l == 2][dr[l == 2] == 2.0E-02], min_lambda[l == 2][dr[l == 2] == 2.0E-02], ".-", label = r"$\Delta \rho = 2/100$")

ax[2][1].legend()
ax[2][1].set_xlabel(r"$\max(\psi)$")
ax[2][1].set_ylabel(r"$\min(\lambda)$")

plt.show()

# %%
fig, ax = plt.subplots(figsize = (16, 18), nrows=3, ncols=2)

plt.suptitle(r"Characterization for RBS $l = 3$")

ax[0][0].set_title(r"Lapse $\log\,\alpha$ Minimum Value")
ax[0][0].plot(max_psi[l == 3][dr[l == 3] == 8.0E-02], np.log(min_alpha[l == 3][dr[l == 3] == 8.0E-02]), ".-", label = r"$\Delta \rho = 8/100$")
ax[0][0].plot(max_psi[l == 3][dr[l == 3] == 4.0E-02], np.log(min_alpha[l == 3][dr[l == 3] == 4.0E-02]), ".-", label = r"$\Delta \rho = 4/100$")
ax[0][0].plot(max_psi[l == 3][dr[l == 3] == 2.0E-02], np.log(min_alpha[l == 3][dr[l == 3] == 2.0E-02]), ".-", label = r"$\Delta \rho = 2/100$")

ax[0][0].legend()
ax[0][0].set_xlabel(r"$\max(\psi)$")
ax[0][0].set_ylabel(r"$\min(\log\,\alpha)$")

ax[0][1].set_title(r"Shift $\beta$ Minimum Value")
ax[0][1].plot(max_psi[l == 3][dr[l == 3] == 8.0E-02], min_beta[l == 3][dr[l == 3] == 8.0E-02], ".-", label = r"$\Delta \rho = 8/100$")
ax[0][1].plot(max_psi[l == 3][dr[l == 3] == 4.0E-02], min_beta[l == 3][dr[l == 3] == 4.0E-02], ".-", label = r"$\Delta \rho = 4/100$")
ax[0][1].plot(max_psi[l == 3][dr[l == 3] == 2.0E-02], min_beta[l == 3][dr[l == 3] == 2.0E-02], ".-", label = r"$\Delta \rho = 2/100$")

ax[0][1].legend()
ax[0][1].set_xlabel(r"$\max(\psi)$")
ax[0][1].set_ylabel(r"$\min(\beta)$")

ax[1][0].set_title(r"Metric $\frac{1}{2}\,\log\,\gamma_{rr}$ Maximum Value")
ax[1][0].plot(max_psi[l == 3][dr[l == 3] == 8.0E-02], 0.5 * np.log(max_metric[l == 3][dr[l == 3] == 8.0E-02]), ".-", label = r"$\Delta \rho = 8/100$")
ax[1][0].plot(max_psi[l == 3][dr[l == 3] == 4.0E-02], 0.5 * np.log(max_metric[l == 3][dr[l == 3] == 4.0E-02]), ".-", label = r"$\Delta \rho = 4/100$")
ax[1][0].plot(max_psi[l == 3][dr[l == 3] == 2.0E-02], 0.5 * np.log(max_metric[l == 3][dr[l == 3] == 2.0E-02]), ".-", label = r"$\Delta \rho = 2/100$")

ax[1][0].legend()
ax[1][0].set_xlabel(r"$\max(\psi)$")
ax[1][0].set_ylabel(r"$\max(\log\,\gamma_{r r})$")

ax[1][1].set_title(r"Metric $\frac{1}{2}\,\log\,(\gamma_{\varphi \varphi} / \rho^2)$ Maximum Value")
ax[1][1].plot(max_psi[l == 3][dr[l == 3] == 8.0E-02], 0.5 * np.log(max_a_metric[l == 3][dr[l == 3] == 8.0E-02]), ".-", label = r"$\Delta \rho = 8/100$")
ax[1][1].plot(max_psi[l == 3][dr[l == 3] == 4.0E-02], 0.5 * np.log(max_a_metric[l == 3][dr[l == 3] == 4.0E-02]), ".-", label = r"$\Delta \rho = 4/100$")
ax[1][1].plot(max_psi[l == 3][dr[l == 3] == 2.0E-02], 0.5 * np.log(max_a_metric[l == 3][dr[l == 3] == 2.0E-02]), ".-", label = r"$\Delta \rho = 2/100$")

ax[1][1].legend()
ax[1][1].set_xlabel(r"$\max(\psi)$")
ax[1][1].set_ylabel(r"$\max(\log\,(\gamma_{\varphi \varphi}/\rho^2))$")

ax[2][0].set_title(r"Scalar Field Frequency $\omega$")
ax[2][0].plot(max_psi[l == 3][dr[l == 3] == 8.0E-02], w[l == 3][dr[l == 3] == 8.0E-02], ".-", label = r"$\omega = 8/100$")
ax[2][0].plot(max_psi[l == 3][dr[l == 3] == 4.0E-02], w[l == 3][dr[l == 3] == 4.0E-02], ".-", label = r"$\omega = 4/100$")
ax[2][0].plot(max_psi[l == 3][dr[l == 3] == 2.0E-02], w[l == 3][dr[l == 3] == 2.0E-02], ".-", label = r"$\omega = 2/100$")

ax[2][0].legend()
ax[2][0].set_xlabel(r"$\max(\psi)$")
ax[2][0].set_ylabel(r"$\omega$")

ax[2][1].set_title(r"Regularization Variable $\lambda$ Minimum Value")
ax[2][1].plot(max_psi[l == 3][dr[l == 3] == 8.0E-02], min_lambda[l == 3][dr[l == 3] == 8.0E-02], ".-", label = r"$\Delta \rho = 8/100$")
ax[2][1].plot(max_psi[l == 3][dr[l == 3] == 4.0E-02], min_lambda[l == 3][dr[l == 3] == 4.0E-02], ".-", label = r"$\Delta \rho = 4/100$")
ax[2][1].plot(max_psi[l == 3][dr[l == 3] == 2.0E-02], min_lambda[l == 3][dr[l == 3] == 2.0E-02], ".-", label = r"$\Delta \rho = 2/100$")

ax[2][1].legend()
ax[2][1].set_xlabel(r"$\max(\psi)$")
ax[2][1].set_ylabel(r"$\min(\lambda)$")

plt.show()

# %%
fig, ax = plt.subplots(figsize = (16, 18), nrows=3, ncols=2)

plt.suptitle(r"Characterization for RBS $l = 4$")

ax[0][0].set_title(r"Lapse $\log\,\alpha$ Minimum Value")
ax[0][0].plot(max_psi[l == 4][dr[l == 4] == 8.0E-02], np.log(min_alpha[l == 4][dr[l == 4] == 8.0E-02]), ".-", label = r"$\Delta \rho = 8/100$")
ax[0][0].plot(max_psi[l == 4][dr[l == 4] == 4.0E-02], np.log(min_alpha[l == 4][dr[l == 4] == 4.0E-02]), ".-", label = r"$\Delta \rho = 4/100$")
ax[0][0].plot(max_psi[l == 4][dr[l == 4] == 2.0E-02], np.log(min_alpha[l == 4][dr[l == 4] == 2.0E-02]), ".-", label = r"$\Delta \rho = 2/100$")

ax[0][0].legend()
ax[0][0].set_xlabel(r"$\max(\psi)$")
ax[0][0].set_ylabel(r"$\min(\log\,\alpha)$")

ax[0][1].set_title(r"Shift $\beta$ Minimum Value")
ax[0][1].plot(max_psi[l == 4][dr[l == 4] == 8.0E-02], min_beta[l == 4][dr[l == 4] == 8.0E-02], ".-", label = r"$\Delta \rho = 8/100$")
ax[0][1].plot(max_psi[l == 4][dr[l == 4] == 4.0E-02], min_beta[l == 4][dr[l == 4] == 4.0E-02], ".-", label = r"$\Delta \rho = 4/100$")
ax[0][1].plot(max_psi[l == 4][dr[l == 4] == 2.0E-02], min_beta[l == 4][dr[l == 4] == 2.0E-02], ".-", label = r"$\Delta \rho = 2/100$")

ax[0][1].legend()
ax[0][1].set_xlabel(r"$\max(\psi)$")
ax[0][1].set_ylabel(r"$\min(\beta)$")

ax[1][0].set_title(r"Metric $\frac{1}{2}\,\log\,\gamma_{rr}$ Maximum Value")
ax[1][0].plot(max_psi[l == 4][dr[l == 4] == 8.0E-02], 0.5 * np.log(max_metric[l == 4][dr[l == 4] == 8.0E-02]), ".-", label = r"$\Delta \rho = 8/100$")
ax[1][0].plot(max_psi[l == 4][dr[l == 4] == 4.0E-02], 0.5 * np.log(max_metric[l == 4][dr[l == 4] == 4.0E-02]), ".-", label = r"$\Delta \rho = 4/100$")
ax[1][0].plot(max_psi[l == 4][dr[l == 4] == 2.0E-02], 0.5 * np.log(max_metric[l == 4][dr[l == 4] == 2.0E-02]), ".-", label = r"$\Delta \rho = 2/100$")

ax[1][0].legend()
ax[1][0].set_xlabel(r"$\max(\psi)$")
ax[1][0].set_ylabel(r"$\max(\log\,\gamma_{r r})$")

ax[1][1].set_title(r"Metric $\frac{1}{2}\,\log\,(\gamma_{\varphi \varphi} / \rho^2)$ Maximum Value")
ax[1][1].plot(max_psi[l == 4][dr[l == 4] == 8.0E-02], 0.5 * np.log(max_a_metric[l == 4][dr[l == 4] == 8.0E-02]), ".-", label = r"$\Delta \rho = 8/100$")
ax[1][1].plot(max_psi[l == 4][dr[l == 4] == 4.0E-02], 0.5 * np.log(max_a_metric[l == 4][dr[l == 4] == 4.0E-02]), ".-", label = r"$\Delta \rho = 4/100$")
ax[1][1].plot(max_psi[l == 4][dr[l == 4] == 2.0E-02], 0.5 * np.log(max_a_metric[l == 4][dr[l == 4] == 2.0E-02]), ".-", label = r"$\Delta \rho = 2/100$")

ax[1][1].legend()
ax[1][1].set_xlabel(r"$\max(\psi)$")
ax[1][1].set_ylabel(r"$\max(\log\,(\gamma_{\varphi \varphi}/\rho^2))$")

ax[2][0].set_title(r"Scalar Field Frequency $\omega$")
ax[2][0].plot(max_psi[l == 4][dr[l == 4] == 8.0E-02], w[l == 4][dr[l == 4] == 8.0E-02], ".-", label = r"$\omega = 8/100$")
ax[2][0].plot(max_psi[l == 4][dr[l == 4] == 4.0E-02], w[l == 4][dr[l == 4] == 4.0E-02], ".-", label = r"$\omega = 4/100$")
ax[2][0].plot(max_psi[l == 4][dr[l == 4] == 2.0E-02], w[l == 4][dr[l == 4] == 2.0E-02], ".-", label = r"$\omega = 2/100$")

ax[2][0].legend()
ax[2][0].set_xlabel(r"$\max(\psi)$")
ax[2][0].set_ylabel(r"$\omega$")

ax[2][1].set_title(r"Regularization Variable $\lambda$ Minimum Value")
ax[2][1].plot(max_psi[l == 4][dr[l == 4] == 8.0E-02], min_lambda[l == 4][dr[l == 4] == 8.0E-02], ".-", label = r"$\Delta \rho = 8/100$")
ax[2][1].plot(max_psi[l == 4][dr[l == 4] == 4.0E-02], min_lambda[l == 4][dr[l == 4] == 4.0E-02], ".-", label = r"$\Delta \rho = 4/100$")
ax[2][1].plot(max_psi[l == 4][dr[l == 4] == 2.0E-02], min_lambda[l == 4][dr[l == 4] == 2.0E-02], ".-", label = r"$\Delta \rho = 2/100$")

ax[2][1].legend()
ax[2][1].set_xlabel(r"$\max(\psi)$")
ax[2][1].set_ylabel(r"$\min(\lambda)$")

plt.show()

# %%
fig, ax = plt.subplots(figsize = (16, 18), nrows=3, ncols=2)

plt.suptitle(r"Characterization for RBS $l = 5$")

ax[0][0].set_title(r"Lapse $\log\,\alpha$ Minimum Value")
ax[0][0].plot(max_psi[l == 5][dr[l == 5] == 8.0E-02], np.log(min_alpha[l == 5][dr[l == 5] == 8.0E-02]), ".-", label = r"$\Delta \rho = 8/100$")
ax[0][0].plot(max_psi[l == 5][dr[l == 5] == 4.0E-02], np.log(min_alpha[l == 5][dr[l == 5] == 4.0E-02]), ".-", label = r"$\Delta \rho = 4/100$")
ax[0][0].plot(max_psi[l == 5][dr[l == 5] == 2.0E-02], np.log(min_alpha[l == 5][dr[l == 5] == 2.0E-02]), ".-", label = r"$\Delta \rho = 2/100$")

ax[0][0].legend()
ax[0][0].set_xlabel(r"$\max(\psi)$")
ax[0][0].set_ylabel(r"$\min(\log\,\alpha)$")

ax[0][1].set_title(r"Shift $\beta$ Minimum Value")
ax[0][1].plot(max_psi[l == 5][dr[l == 5] == 8.0E-02], min_beta[l == 5][dr[l == 5] == 8.0E-02], ".-", label = r"$\Delta \rho = 8/100$")
ax[0][1].plot(max_psi[l == 5][dr[l == 5] == 4.0E-02], min_beta[l == 5][dr[l == 5] == 4.0E-02], ".-", label = r"$\Delta \rho = 4/100$")
ax[0][1].plot(max_psi[l == 5][dr[l == 5] == 2.0E-02], min_beta[l == 5][dr[l == 5] == 2.0E-02], ".-", label = r"$\Delta \rho = 2/100$")

ax[0][1].legend()
ax[0][1].set_xlabel(r"$\max(\psi)$")
ax[0][1].set_ylabel(r"$\min(\beta)$")

ax[1][0].set_title(r"Metric $\frac{1}{2}\,\log\,\gamma_{rr}$ Maximum Value")
ax[1][0].plot(max_psi[l == 5][dr[l == 5] == 8.0E-02], 0.5 * np.log(max_metric[l == 5][dr[l == 5] == 8.0E-02]), ".-", label = r"$\Delta \rho = 8/100$")
ax[1][0].plot(max_psi[l == 5][dr[l == 5] == 4.0E-02], 0.5 * np.log(max_metric[l == 5][dr[l == 5] == 4.0E-02]), ".-", label = r"$\Delta \rho = 4/100$")
ax[1][0].plot(max_psi[l == 5][dr[l == 5] == 2.0E-02], 0.5 * np.log(max_metric[l == 5][dr[l == 5] == 2.0E-02]), ".-", label = r"$\Delta \rho = 2/100$")

ax[1][0].legend()
ax[1][0].set_xlabel(r"$\max(\psi)$")
ax[1][0].set_ylabel(r"$\max(\log\,\gamma_{r r})$")

ax[1][1].set_title(r"Metric $\frac{1}{2}\,\log\,(\gamma_{\varphi \varphi} / \rho^2)$ Maximum Value")
ax[1][1].plot(max_psi[l == 5][dr[l == 5] == 8.0E-02], 0.5 * np.log(max_a_metric[l == 5][dr[l == 5] == 8.0E-02]), ".-", label = r"$\Delta \rho = 8/100$")
ax[1][1].plot(max_psi[l == 5][dr[l == 5] == 4.0E-02], 0.5 * np.log(max_a_metric[l == 5][dr[l == 5] == 4.0E-02]), ".-", label = r"$\Delta \rho = 4/100$")
ax[1][1].plot(max_psi[l == 5][dr[l == 5] == 2.0E-02], 0.5 * np.log(max_a_metric[l == 5][dr[l == 5] == 2.0E-02]), ".-", label = r"$\Delta \rho = 2/100$")

ax[1][1].legend()
ax[1][1].set_xlabel(r"$\max(\psi)$")
ax[1][1].set_ylabel(r"$\max(\log\,(\gamma_{\varphi \varphi}/\rho^2))$")

ax[2][0].set_title(r"Scalar Field Frequency $\omega$")
ax[2][0].plot(max_psi[l == 5][dr[l == 5] == 8.0E-02], w[l == 5][dr[l == 5] == 8.0E-02], ".-", label = r"$\omega = 8/100$")
ax[2][0].plot(max_psi[l == 5][dr[l == 5] == 4.0E-02], w[l == 5][dr[l == 5] == 4.0E-02], ".-", label = r"$\omega = 4/100$")
ax[2][0].plot(max_psi[l == 5][dr[l == 5] == 2.0E-02], w[l == 5][dr[l == 5] == 2.0E-02], ".-", label = r"$\omega = 2/100$")

ax[2][0].legend()
ax[2][0].set_xlabel(r"$\max(\psi)$")
ax[2][0].set_ylabel(r"$\omega$")

ax[2][1].set_title(r"Regularization Variable $\lambda$ Minimum Value")
ax[2][1].plot(max_psi[l == 5][dr[l == 5] == 8.0E-02], min_lambda[l == 5][dr[l == 5] == 8.0E-02], ".-", label = r"$\Delta \rho = 8/100$")
ax[2][1].plot(max_psi[l == 5][dr[l == 5] == 4.0E-02], min_lambda[l == 5][dr[l == 5] == 4.0E-02], ".-", label = r"$\Delta \rho = 4/100$")
ax[2][1].plot(max_psi[l == 5][dr[l == 5] == 2.0E-02], min_lambda[l == 5][dr[l == 5] == 2.0E-02], ".-", label = r"$\Delta \rho = 2/100$")

ax[2][1].legend()
ax[2][1].set_xlabel(r"$\max(\psi)$")
ax[2][1].set_ylabel(r"$\min(\lambda)$")

plt.show()

# %%
fig, ax = plt.subplots(figsize = (16, 18), nrows=3, ncols=2)

plt.suptitle(r"Characterization for RBS $l = 6$")

ax[0][0].set_title(r"Lapse $\log\,\alpha$ Minimum Value")
ax[0][0].plot(max_psi[l == 6][dr[l == 6] == 8.0E-02], np.log(min_alpha[l == 6][dr[l == 6] == 8.0E-02]), ".-", label = r"$\Delta \rho = 8/100$")
ax[0][0].plot(max_psi[l == 6][dr[l == 6] == 4.0E-02], np.log(min_alpha[l == 6][dr[l == 6] == 4.0E-02]), ".-", label = r"$\Delta \rho = 4/100$")
ax[0][0].plot(max_psi[l == 6][dr[l == 6] == 2.0E-02], np.log(min_alpha[l == 6][dr[l == 6] == 2.0E-02]), ".-", label = r"$\Delta \rho = 2/100$")

ax[0][0].legend()
ax[0][0].set_xlabel(r"$\max(\psi)$")
ax[0][0].set_ylabel(r"$\min(\log\,\alpha)$")

ax[0][1].set_title(r"Shift $\beta$ Minimum Value")
ax[0][1].plot(max_psi[l == 6][dr[l == 6] == 8.0E-02], min_beta[l == 6][dr[l == 6] == 8.0E-02], ".-", label = r"$\Delta \rho = 8/100$")
ax[0][1].plot(max_psi[l == 6][dr[l == 6] == 4.0E-02], min_beta[l == 6][dr[l == 6] == 4.0E-02], ".-", label = r"$\Delta \rho = 4/100$")
ax[0][1].plot(max_psi[l == 6][dr[l == 6] == 2.0E-02], min_beta[l == 6][dr[l == 6] == 2.0E-02], ".-", label = r"$\Delta \rho = 2/100$")

ax[0][1].legend()
ax[0][1].set_xlabel(r"$\max(\psi)$")
ax[0][1].set_ylabel(r"$\min(\beta)$")

ax[1][0].set_title(r"Metric $\frac{1}{2}\,\log\,\gamma_{rr}$ Maximum Value")
ax[1][0].plot(max_psi[l == 6][dr[l == 6] == 8.0E-02], 0.5 * np.log(max_metric[l == 6][dr[l == 6] == 8.0E-02]), ".-", label = r"$\Delta \rho = 8/100$")
ax[1][0].plot(max_psi[l == 6][dr[l == 6] == 4.0E-02], 0.5 * np.log(max_metric[l == 6][dr[l == 6] == 4.0E-02]), ".-", label = r"$\Delta \rho = 4/100$")
ax[1][0].plot(max_psi[l == 6][dr[l == 6] == 2.0E-02], 0.5 * np.log(max_metric[l == 6][dr[l == 6] == 2.0E-02]), ".-", label = r"$\Delta \rho = 2/100$")

ax[1][0].legend()
ax[1][0].set_xlabel(r"$\max(\psi)$")
ax[1][0].set_ylabel(r"$\max(\log\,\gamma_{r r})$")

ax[1][1].set_title(r"Metric $\frac{1}{2}\,\log\,(\gamma_{\varphi \varphi} / \rho^2)$ Maximum Value")
ax[1][1].plot(max_psi[l == 6][dr[l == 6] == 8.0E-02], 0.5 * np.log(max_a_metric[l == 6][dr[l == 6] == 8.0E-02]), ".-", label = r"$\Delta \rho = 8/100$")
ax[1][1].plot(max_psi[l == 6][dr[l == 6] == 4.0E-02], 0.5 * np.log(max_a_metric[l == 6][dr[l == 6] == 4.0E-02]), ".-", label = r"$\Delta \rho = 4/100$")
ax[1][1].plot(max_psi[l == 6][dr[l == 6] == 2.0E-02], 0.5 * np.log(max_a_metric[l == 6][dr[l == 6] == 2.0E-02]), ".-", label = r"$\Delta \rho = 2/100$")

ax[1][1].legend()
ax[1][1].set_xlabel(r"$\max(\psi)$")
ax[1][1].set_ylabel(r"$\max(\log\,(\gamma_{\varphi \varphi}/\rho^2))$")

ax[2][0].set_title(r"Scalar Field Frequency $\omega$")
ax[2][0].plot(max_psi[l == 6][dr[l == 6] == 8.0E-02], w[l == 6][dr[l == 6] == 8.0E-02], ".-", label = r"$\omega = 8/100$")
ax[2][0].plot(max_psi[l == 6][dr[l == 6] == 4.0E-02], w[l == 6][dr[l == 6] == 4.0E-02], ".-", label = r"$\omega = 4/100$")
ax[2][0].plot(max_psi[l == 6][dr[l == 6] == 2.0E-02], w[l == 6][dr[l == 6] == 2.0E-02], ".-", label = r"$\omega = 2/100$")

ax[2][0].legend()
ax[2][0].set_xlabel(r"$\max(\psi)$")
ax[2][0].set_ylabel(r"$\omega$")

ax[2][1].set_title(r"Regularization Variable $\lambda$ Minimum Value")
ax[2][1].plot(max_psi[l == 6][dr[l == 6] == 8.0E-02], min_lambda[l == 6][dr[l == 6] == 8.0E-02], ".-", label = r"$\Delta \rho = 8/100$")
ax[2][1].plot(max_psi[l == 6][dr[l == 6] == 4.0E-02], min_lambda[l == 6][dr[l == 6] == 4.0E-02], ".-", label = r"$\Delta \rho = 4/100$")
ax[2][1].plot(max_psi[l == 6][dr[l == 6] == 2.0E-02], min_lambda[l == 6][dr[l == 6] == 2.0E-02], ".-", label = r"$\Delta \rho = 2/100$")

ax[2][1].legend()
ax[2][1].set_xlabel(r"$\max(\psi)$")
ax[2][1].set_ylabel(r"$\min(\lambda)$")

plt.show()
